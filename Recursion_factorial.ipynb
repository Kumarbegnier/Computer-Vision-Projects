# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumarbegnier/Computer-Vision-Projects/blob/main/Recursion_factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    if n == 0 or n == 1:   # Base case
        return 1
    else:
        return n * factorial(n-1)

print(factorial(7))
# Out:
# 5040
